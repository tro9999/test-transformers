# %%
#from text2sql.data_utils import data_utils
from text2sql.nlp import Nlp
# Out:
# 2023-06-21 14:19:21.025349: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 14:19:21.075725: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-21 14:19:21.076963: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-21 14:19:21.917251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All model checkpoint layers were used when initializing TFDistilBertForQuestionAnswering.
#
# All the layers of TFDistilBertForQuestionAnswering were initialized from the model checkpoint at distilbert-base-uncased-distilled-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForQuestionAnswering for predictions without further training.

# %%
#import nltk
#nltk.download('wordnet')
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')

# %%
#from text2sql.data_utils import data_utils
#getSchema=data_utils("data","schema")
#getSchema.get_schema_for_csv("data/oura_sleep.xxx")
nlp = Nlp("data","schema" )

# %%
question = "how did i sleep?"
distinct = False

# %%
# sql_query = nlp.get_sql_query(df, question, distinct=distinct)
sql_query = nlp.get_sql_query(question)
print("SQL=",sql_query)
print("QUESTION=",question)
# Out:
# {'name': 'oura_sleep_summary', 'desciption': 'This sleep summary data provides insights into your sleep quality for a specific night. It includes details such as the date of the sleep period, total sleep duration, sleep efficiency percentage, sleep score representing overall sleep quality, and the distribution of different sleep stages (REM, light, and deep sleep). You can use this information to assess how well you slept, the amount of restful sleep obtained, and any potential sleep disturbances. Additionally, metrics like heart rate, restlessness, and temperature deviation offer further context. With these details, you can evaluate your sleep patterns and make adjustments to improve your overall sleep health.', 'keywords': ['Sleep', 'Bedtime', 'Wake-up', 'Duration', 'Deep sleep', 'REM sleep', 'Light sleep', 'Awake time', 'Heart rate', 'Sleep score', 'Efficiency', 'Chapter', 'Temperature', 'Breathing rate', 'Sleep stages', 'Sleep quality', 'Sleep disturbances', 'HRV (Heart rate variability)', 'Sleep schedule'], 'columns': [{'name': 'summary_date', 'keywords': ['date', 'day', 'night', 'sleep date', 'last night', 'latest'], 'type': 'Date', 'desciption': 'The date of the sleep period, representing the day before the sleep period ended'}, {'name': 'bedtime_start', 'keywords': ['sleep start time', 'bedtime start', 'start time', 'when I went to bed', 'bedtime'], 'type': 'Timestamp', 'desciption': 'The local time when the sleep period started'}, {'name': 'bedtime_end', 'keywords': ['sleep end time', 'bedtime end', 'end time', 'when I woke up', 'wake-up time'], 'type': 'Timestamp', 'desciption': 'The local time when the sleep period ended'}, {'name': 'duration', 'keywords': ['sleep length', 'total sleep time', 'how long I slept'], 'type': 'Integer', 'desciption': 'The total duration of the sleep period in seconds', 'summable': 'True'}, {'name': 'total', 'keywords': ['total sleep duration', 'overall sleep time', 'total time asleep', 'total sleep'], 'type': 'Integer', 'desciption': 'The total amount of sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'awake', 'keywords': ['awake time', 'time awake', 'time spent awake', 'wakeful period'], 'type': 'Integer', 'desciption': 'The total amount of awake time in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'rem', 'keywords': ['REM sleep', 'rapid eye movement sleep', 'active dreaming phase', 'dreaming'], 'type': 'Integer', 'desciption': 'The total amount of REM sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'light', 'keywords': ['light sleep', 'light restful phase', 'light rest'], 'type': 'Integer', 'desciption': 'The total amount of light sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'deep', 'keywords': ['deep sleep', 'deep restorative phase', 'deep rest'], 'type': 'Integer', 'desciption': 'The total amount of deep sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'hr_lowest', 'keywords': ['lowest heart rate', 'minimum pulse rate', 'lowest heartbeat', 'minimum heart rate'], 'type': 'Integer', 'desciption': 'The lowest heart rate (5-minute sliding average) registered during the sleep period', 'summable': 'True'}, {'name': 'hr_average', 'keywords': ['average heart rate', 'mean pulse rate', 'typical heartbeat', 'mean heart rate'], 'type': 'Integer', 'desciption': 'The average heart rate registered during the sleep period', 'summable': 'True'}, {'name': 'hr_5min', 'keywords': ['heart rate intervals', 'heartbeat readings', 'heartbeats'], 'type': 'String', 'desciption': 'The average heart rate for each beginning 5 minutes of the sleep period'}, {'name': 'efficiency', 'keywords': ['sleep efficiency percentage', 'sleep effectiveness', 'how well I slept'], 'type': 'Integer', 'desciption': 'The sleep efficiency percentage, representing the proportion of time spent asleep', 'summable': 'True'}, {'name': 'onset_latency', 'keywords': [ ...
# QUESTION  how did i sleep?
# COLNAME  summary_date
# COLTYPE  Date
# COL QUERY number of date?
# QA  number of date? how did i sleep?
# ANSWER
# ANSWER IDX  1 0
# Answer:
# Start Score: [0.19063073 0.33991632 0.02096082 0.04233902 0.00822489 0.02334666
#  0.1127573  0.01067204 0.14817065 0.07737625 0.00225544 0.02334988]
# End Score: [0.25080156 0.13764341 0.0135181  0.0943227  0.01782954 0.22103369
#  0.00548769 0.00052171 0.0016328  0.03309018 0.00306546 0.22105312]
# Total Score: 0.08525155
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  []
# filling slots %s %s %s summary_date  0
# COLNAME  bedtime_start
# COLTYPE  Timestamp
# COL QUERY which sleep start time?
# QA  which sleep start time? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  7 12
# Answer: how did i sleep?
# Start Score: [0.04481301 0.21316548 0.0241143  0.00614181 0.00610661 0.00132711
#  0.05072173 0.233245   0.00701727 0.15908301 0.20050736 0.00302577
#  0.05073153]
# End Score: [0.07639019 0.03107014 0.00957941 0.0025422  0.00435867 0.00254784
#  0.41538024 0.0080195  0.00094997 0.00302983 0.02642757 0.00425526
#  0.41544914]
# Total Score: 0.09690143
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s bedtime_start how did i sleep?  0
# COLNAME  bedtime_end
# COLTYPE  Timestamp
# COL QUERY which sleep end time?
# QA  which sleep end time? how did i sleep?
# ANSWER  i sleep? [SEP]
# ANSWER IDX  9 12
# Answer: i sleep?
# Start Score: [0.04155339 0.1391267  0.01408624 0.00820869 0.00521974 0.00123153
#  0.06479591 0.2210001  0.00672828 0.25596616 0.17407483 0.00319882
#  0.06480961]
# End Score: [0.06053862 0.02548295 0.0055672  0.00236654 0.00373245 0.00197862
#  0.43261075 0.00834969 0.00091494 0.00450153 0.01711712 0.00415172
#  0.4326878 ]
# Total Score: 0.11075343
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['i', 'sleep', '?']
# filling slots %s %s %s bedtime_end i sleep?  0
# COLNAME  duration
# COLTYPE  Integer
# COL QUERY number of sleep length?
# QA  number of sleep length? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  7 12
# Answer: how did i sleep?
# Start Score: [0.14524034 0.11521658 0.0143983  0.03085009 0.00518562 0.0036713
#  0.0470328  0.43917814 0.00739676 0.09978386 0.04036951 0.00463766
#  0.04703904]
# End Score: [0.15914473 0.04189175 0.00407846 0.00876403 0.01194712 0.00394774
#  0.37150604 0.01444629 0.0005261  0.00171353 0.00552487 0.00495922
#  0.37155014]
# Total Score: 0.1631767
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s duration how did i sleep?  0
# COLNAME  total
# COLTYPE  Integer
# COL QUERY number of total sleep duration?
# QA  number of total sleep duration? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.09574041 0.11398162 0.00388127 0.02727655 0.00601402 0.00811942
#  0.0029345  0.04771654 0.50290114 0.00914872 0.09282384 0.0380836
#  0.00365554 0.04772273]
# End Score: [0.1441124  0.03437949 0.00139828 0.00481465 0.00202237 0.02714122
#  0.00220563 0.38052827 0.012273   0.00049857 0.00134444 0.00497179
#  0.0037428  0.3805671 ]
# Total Score: 0.19138762
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s total how did i sleep?  0
# COLNAME  awake
# COLTYPE  Integer
# COL QUERY number of awake time?
# QA  number of awake time? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  7 12
# Answer: how did i sleep?
# Start Score: [0.17702675 0.1163749  0.00682389 0.0125684  0.01311354 0.00257196
#  0.05561288 0.27296013 0.00982204 0.10850466 0.16587247 0.00312734
#  0.0556211 ]
# End Score: [2.0373136e-01 2.3650153e-02 2.2194148e-03 3.6839130e-03 2.8101588e-02
#  2.8140037e-03 3.5111469e-01 3.5966609e-03 2.9393131e-04 7.7340432e-04
#  2.5962735e-02 2.9013783e-03 3.5115674e-01]
# Total Score: 0.09585179
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s awake how did i sleep?  0.09585179
# COLNAME  rem
# COLTYPE  Integer
# COL QUERY number of REM sleep?
# QA  number of REM sleep? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.08475088 0.02278074 0.00503303 0.08062106 0.00181759 0.00272635
#  0.00179086 0.06230851 0.5605793  0.00767841 0.05561847 0.04749009
#  0.00448781 0.06231695]
# End Score: [0.12582168 0.00375226 0.00077644 0.0010949  0.02921909 0.00280947
#  0.00158563 0.4041543  0.01407062 0.0004743  0.00110472 0.00658429
#  0.00435634 0.40419602]
# Total Score: 0.22658393
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s rem how did i sleep?  0
# COLNAME  light
# COLTYPE  Integer
# COL QUERY number of light sleep?
# QA  number of light sleep? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  7 12
# Answer: how did i sleep?
# Start Score: [0.1410282  0.07030775 0.00716944 0.04080372 0.00548924 0.0023503
#  0.07466192 0.39375025 0.00928044 0.11260445 0.06287158 0.00501025
#  0.07467249]
# End Score: [0.15244141 0.00920425 0.00087368 0.00941846 0.00394558 0.00218137
#  0.4009408  0.00793302 0.00041675 0.00117946 0.0067025  0.00377855
#  0.40098417]
# Total Score: 0.15788762
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s light how did i sleep?  0
# COLNAME  deep
# COLTYPE  Integer
# COL QUERY number of deep sleep?
# QA  number of deep sleep? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  7 12
# Answer: how did i sleep?
# Start Score: [0.16096264 0.08769174 0.0058296  0.02320793 0.00392854 0.00292169
#  0.08266708 0.34789068 0.0111616  0.113826   0.0717496  0.0054849
#  0.082678  ]
# End Score: [1.8528625e-01 1.4845259e-02 9.8022190e-04 1.3612661e-03 3.7063069e-03
#  2.2162376e-03 3.8718605e-01 6.4943177e-03 3.3707003e-04 9.1236207e-04
#  5.8388938e-03 3.6100107e-03 3.8722581e-01]
# Total Score: 0.13471225
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s deep how did i sleep?  0
# COLNAME  hr_lowest
# COLTYPE  Integer
# COL QUERY number of lowest heart rate?
# QA  number of lowest heart rate? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.0646309  0.1071884  0.0043571  0.03798677 0.0094046  0.00293228
#  0.00106979 0.02719429 0.32362014 0.02137182 0.11772566 0.25371292
#  0.00160757 0.02719779]
# End Score: [0.1666435  0.01837662 0.00082601 0.00416373 0.00143745 0.02543855
#  0.00167909 0.3511031  0.0080228  0.00057325 0.00104285 0.06692972
#  0.00262894 0.35113436]
# Total Score: 0.113634154
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s hr_lowest how did i sleep?  0.113634154
# COLNAME  hr_average
# COLTYPE  Integer
# COL QUERY number of average heart rate?
# QA  number of average heart rate? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.04793688 0.10536495 0.0043997  0.09463318 0.01133176 0.00474603
#  0.00126552 0.0331722  0.27265    0.01765005 0.12731056 0.2447031
#  0.00165971 0.03317637]
# End Score: [0.18670256 0.01819517 0.0007162  0.00311333 0.0014112  0.0176565
#  0.001427   0.35614246 0.00541965 0.00046085 0.00076583 0.04957305
#  0.00224195 0.35617426]
# Total Score: 0.09711091
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s hr_average how did i sleep?  0.09711091
# COLNAME  hr_5min
# COLTYPE  String
# COL QUERY which heart rate intervals?
# QA  which heart rate intervals? how did i sleep?
# ANSWER  sleep? [SEP]
# ANSWER IDX  10 12
# Answer: sleep?
# Start Score: [0.02612288 0.17664249 0.06324863 0.01631316 0.01182275 0.00204042
#  0.034623   0.18109688 0.01131763 0.12728149 0.31226113 0.00260047
#  0.03462905]
# End Score: [0.0466112  0.02879938 0.00612865 0.01263391 0.01839782 0.00210626
#  0.40809414 0.00609609 0.00063807 0.00105015 0.05847138 0.00282378
#  0.40814924]
# Total Score: 0.12744914
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['sleep', '?']
# filling slots %s %s %s hr_5min sleep?  0.12744914
# COLNAME  efficiency
# COLTYPE  Integer
# COL QUERY number of sleep efficiency percentage?
# QA  number of sleep efficiency percentage? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.061066   0.18920694 0.00931541 0.03728741 0.01001822 0.03366394
#  0.00326299 0.05734941 0.26460272 0.01343888 0.12240526 0.13792956
#  0.00309583 0.05735739]
# End Score: [8.3640791e-02 1.4234408e-02 6.6494948e-04 1.3751956e-03 3.8987068e-03
#  6.5653212e-02 2.2952047e-03 4.0121511e-01 6.0929847e-03 3.6831913e-04
#  9.4709796e-04 1.5807210e-02 2.5513002e-03 4.0125552e-01]
# Total Score: 0.1061733
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s efficiency how did i sleep?  0
# COLNAME  onset_latency
# COLTYPE  Integer
# COL QUERY number of sleep onset time?
# QA  number of sleep onset time? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.09686691 0.0570178  0.00652049 0.01814668 0.00535658 0.00663161
#  0.00293162 0.08575547 0.48520184 0.00894961 0.08126891 0.05481678
#  0.00476713 0.0857686 ]
# End Score: [1.0322983e-01 7.1444283e-03 1.3729210e-03 2.6827117e-03 2.5790595e-03
#  6.8299114e-03 1.9306290e-03 4.2724618e-01 8.9865420e-03 3.8600538e-04
#  1.1625274e-03 5.0618257e-03 4.0936363e-03 4.2729390e-01]
# Total Score: 0.20732379
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s onset_latency how did i sleep?  0
# COLNAME  midpoint_time
# COLTYPE  Integer
# COL QUERY number of sleep midpoint?
# QA  number of sleep midpoint? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.11259495 0.06557809 0.00647945 0.01008785 0.02066681 0.0040179
#  0.00210626 0.06718427 0.5143181  0.00769445 0.08274611 0.03518801
#  0.00414436 0.06719331]
# End Score: [0.16679925 0.00795808 0.00119559 0.00344891 0.00072813 0.02593293
#  0.00231518 0.3854931  0.0104279  0.0003918  0.00146861 0.00469596
#  0.00361529 0.38552928]
# Total Score: 0.19828469
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s midpoint_time how did i sleep?  0
# COLNAME  restless
# COLTYPE  Integer
# COL QUERY number of restlessness percentage?
# QA  number of restlessness percentage? how did i sleep?
# ANSWER  sleep? [SEP]
# ANSWER IDX  11 13
# Answer: sleep?
# Start Score: [0.04635174 0.13045363 0.00470986 0.04916449 0.00174179 0.02487916
#  0.00182485 0.03594083 0.2701878  0.02004648 0.1055176  0.27154914
#  0.00168712 0.03594545]
# End Score: [0.1391621  0.00983518 0.00041962 0.00088284 0.0058251  0.09207378
#  0.0023502  0.34732512 0.00390019 0.00036927 0.00060305 0.04826595
#  0.00163414 0.3473535 ]
# Total Score: 0.09432354
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['sleep', '?']
# filling slots %s %s %s restless sleep?  0.09432354
# COLNAME  temperature_delta
# COLTYPE  Decimal
# COL QUERY number of temperature deviation?
# QA  number of temperature deviation? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  7 12
# Answer: how did i sleep?
# Start Score: [0.05043807 0.16981316 0.01524356 0.10936869 0.04923523 0.00320429
#  0.0338677  0.2341311  0.01519824 0.11114616 0.17258118 0.00190031
#  0.0338723 ]
# End Score: [0.10216053 0.05238275 0.0030092  0.00718699 0.1833892  0.005322
#  0.30476427 0.0043588  0.000388   0.00073423 0.02913538 0.00237408
#  0.3047945 ]
# Total Score: 0.07136187
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s temperature_delta how did i sleep?  0.07136187
# COLNAME  breath_average
# COLTYPE  Decimal
# COL QUERY number of average respiratory rate?
# QA  number of average respiratory rate? how did i sleep?
# ANSWER  sleep? [SEP]
# ANSWER IDX  11 13
# Answer: sleep?
# Start Score: [0.04928742 0.175032   0.00541965 0.12534441 0.01037986 0.01234962
#  0.00163153 0.03168695 0.19782263 0.01237066 0.08577188 0.25955835
#  0.00165369 0.03169129]
# End Score: [0.1728097  0.03866497 0.00086996 0.00504304 0.00424789 0.04160586
#  0.00172948 0.33787194 0.00486674 0.00042    0.00071032 0.05111829
#  0.00213596 0.33790582]
# Total Score: 0.087706275
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['sleep', '?']
# filling slots %s %s %s breath_average sleep?  0.087706275
# COLNAME  score
# COLTYPE  Integer
# COL QUERY number of sleep quality score?
# QA  number of sleep quality score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.13962732 0.15095675 0.00978495 0.03732001 0.00650993 0.0139504
#  0.00339308 0.04145458 0.31134254 0.01028971 0.17249756 0.05854695
#  0.00286609 0.04146015]
# End Score: [0.18911141 0.02899476 0.00232541 0.00510043 0.01332188 0.06169621
#  0.00536869 0.33611828 0.00815631 0.00041849 0.00133548 0.00808655
#  0.00381965 0.33614644]
# Total Score: 0.10465669
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score how did i sleep?  0
# COLNAME  score_total
# COLTYPE  Integer
# COL QUERY number of sleep duration score?
# QA  number of sleep duration score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.09742852 0.09096446 0.00630433 0.01680656 0.00736304 0.01045858
#  0.0032818  0.04682558 0.44523624 0.0113539  0.15896635 0.05473411
#  0.00344435 0.04683222]
# End Score: [0.1386158  0.01153852 0.00170936 0.00450719 0.01013544 0.02050646
#  0.0027907  0.39125246 0.0112952  0.00053604 0.00149204 0.00983798
#  0.00449412 0.39128876]
# Total Score: 0.17421593
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_total how did i sleep?  0
# COLNAME  score_rem
# COLTYPE  Integer
# COL QUERY number of REM sleep score?
# QA  number of REM sleep score? how did i sleep?
# ANSWER  rem sleep score? [SEP] how did i sleep? [SEP]
# ANSWER IDX  3 14
# Answer: rem sleep score?  how did i sleep?
# Start Score: [0.0760088  0.05402962 0.00648229 0.4875379  0.00166579 0.00242054
#  0.00460472 0.00158119 0.03089541 0.23492223 0.00511765 0.04620869
#  0.01565657 0.00196919 0.0308994 ]
# End Score: [0.18381329 0.00913178 0.00143442 0.00144896 0.02007516 0.00310063
#  0.03267786 0.00381565 0.3618097  0.01082837 0.00045987 0.00122446
#  0.00411557 0.00421689 0.3618474 ]
# Total Score: 0.17641433
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['rem', 'sleep', 'score', '?', 'how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_rem rem sleep score?  how did i sleep?  0
# COLNAME  score_deep
# COLTYPE  Integer
# COL QUERY number of deep sleep score?
# QA  number of deep sleep score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.16292697 0.1010251  0.00665774 0.07092984 0.00265469 0.01863385
#  0.00359191 0.04988227 0.34061757 0.01264009 0.14185822 0.03529843
#  0.00339457 0.04988879]
# End Score: [0.18843272 0.01173151 0.00124306 0.00143879 0.00364699 0.07366002
#  0.00398225 0.34845862 0.00822141 0.00043649 0.00093126 0.0056808
#  0.0036469  0.34848922]
# Total Score: 0.118701555
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_deep how did i sleep?  0
# COLNAME  score_efficiency
# COLTYPE  Integer
# COL QUERY number of sleep efficiency score?
# QA  number of sleep efficiency score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.09803256 0.10520502 0.00999043 0.03505966 0.00843405 0.00946578
#  0.00309561 0.03923701 0.3367145  0.01223682 0.18787736 0.11227955
#  0.0031292  0.0392425 ]
# End Score: [0.15651768 0.01501272 0.00164127 0.00201159 0.01047185 0.03932292
#  0.00390096 0.368965   0.0073267  0.000405   0.00124398 0.02010102
#  0.00407788 0.36900148]
# Total Score: 0.12424815
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_efficiency how did i sleep?  0
# COLNAME  score_latency
# COLTYPE  Integer
# COL QUERY number of sleep onset latency score?
# QA  number of sleep onset latency score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  10 15
# Answer: how did i sleep?
# Start Score: [0.06001978 0.09579533 0.00637653 0.01890648 0.00466635 0.10579411
#  0.00240003 0.01053831 0.00276247 0.06898123 0.38973734 0.01390065
#  0.09474784 0.05297606 0.00340949 0.06898803]
# End Score: [7.3983759e-02 4.9493955e-03 7.9854322e-04 1.5007117e-03 1.5797855e-03
#  4.1530232e-04 2.1180548e-03 2.0901412e-02 2.3742998e-03 4.3601602e-01
#  6.7968508e-03 4.3226511e-04 1.1575265e-03 6.7118313e-03 4.2202929e-03
#  4.3604389e-01]
# Total Score: 0.16994259
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_latency how did i sleep?  0
# COLNAME  score_disturbances
# COLTYPE  Integer
# COL QUERY number of sleep disturbances score?
# QA  number of sleep disturbances score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.08450488 0.07306948 0.0086905  0.044489   0.00626219 0.01169209
#  0.00382124 0.05306891 0.46641645 0.01075167 0.11054136 0.06983698
#  0.00377879 0.0530765 ]
# End Score: [0.12249245 0.00409062 0.00090193 0.00107994 0.00964837 0.00970641
#  0.00252626 0.4097337  0.01127623 0.00049222 0.00101767 0.01279339
#  0.00446891 0.40977192]
# Total Score: 0.19112436
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_disturbances how did i sleep?  0
# COLNAME  score_alignment
# COLTYPE  Integer
# COL QUERY number of sleep schedule alignment score?
# QA  number of sleep schedule alignment score? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  9 14
# Answer: how did i sleep?
# Start Score: [0.05719589 0.07055335 0.00794124 0.03279701 0.01301191 0.01630745
#  0.0103413  0.00251381 0.04274175 0.4776819  0.00966276 0.13536575
#  0.07794699 0.00319199 0.04274698]
# End Score: [0.15202664 0.00810865 0.00173676 0.00755492 0.01752174 0.0076172
#  0.02137501 0.00267714 0.3749689  0.01159023 0.00050837 0.0016749
#  0.01336952 0.00426126 0.37500882]
# Total Score: 0.17913494
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s score_alignment how did i sleep?  0
# COLNAME  hypnogram_5min
# COLTYPE  String
# COL QUERY which sleep stage sequence?
# QA  which sleep stage sequence? how did i sleep?
# ANSWER  which sleep stage sequence? [SEP] how did i sleep? [SEP]
# ANSWER IDX  1 12
# Answer: which sleep stage sequence?  how did i sleep?
# Start Score: [0.03106336 0.39381504 0.05846267 0.01157988 0.01552287 0.00169839
#  0.04245825 0.15480699 0.00563087 0.060173   0.17997316 0.00234923
#  0.04246633]
# End Score: [0.05224922 0.1018545  0.01266191 0.00943966 0.01445186 0.00188158
#  0.38548392 0.00462777 0.00055012 0.00090855 0.02751418 0.0028277
#  0.38554904]
# Total Score: 0.15183501
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['which', 'sleep', 'stage', 'sequence', '?', 'how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s hypnogram_5min which sleep stage sequence?  how did i sleep?  0
# COLNAME  rmssd
# COLTYPE  Integer
# COL QUERY number of average HRV?
# QA  number of average HRV? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  8 13
# Answer: how did i sleep?
# Start Score: [0.07711805 0.09603669 0.00457905 0.0736668  0.16321552 0.00282567
#  0.00105773 0.02807165 0.26742366 0.01204601 0.08947452 0.15508269
#  0.00132702 0.02807502]
# End Score: [0.18964234 0.01604544 0.00079345 0.0106816  0.00436938 0.18083522
#  0.0025433  0.27621683 0.00641478 0.00047155 0.00101971 0.03277592
#  0.00194811 0.27624238]
# Total Score: 0.07387374
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s rmssd how did i sleep?  0.07387374
# COLNAME  rmssd_5min
# COLTYPE  String
# COL QUERY which HRV per 5 minutes?
# QA  which HRV per 5 minutes? how did i sleep?
# ANSWER  how did i sleep? [SEP]
# ANSWER IDX  9 14
# Answer: how did i sleep?
# Start Score: [0.0348985  0.2497297  0.10427646 0.00328998 0.00511993 0.00303215
#  0.00105307 0.00105702 0.04821973 0.30863333 0.01707842 0.05650763
#  0.1169633  0.00191372 0.04822708]
# End Score: [0.05040238 0.01443618 0.0074071  0.00682398 0.00044819 0.00045169
#  0.00198194 0.00103981 0.44570026 0.00586094 0.00059284 0.00085191
#  0.01633573 0.00190302 0.445764  ]
# Total Score: 0.13757762
# FIND  ['how', 'did', 'i', 'sleep', '?']
# FIND  ['how', 'did', 'i', 'sleep', '?']
# filling slots %s %s %s rmssd_5min how did i sleep?  0.13757762
# SLOTS  [('rmssd_5min', 'String', 'how did i sleep? ', 0.13757762)]
# GOT SLOTS  [('rmssd_5min', 'String', 'how did i sleep? ', 0.13757762)]
# 2023-06-21 14:19:34.781874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype string
# 	 [[{{node inputs}}]]
# 1/1 [==============================] - 0s 133ms/step
# QUESTION  SELECT {} FROM {}
# QUESTION2  SELECT * FROM oura_sleep_summary
# SQL= SELECT * FROM oura_sleep_summary WHERE rmssd_5min = 'how did i sleep? '
# QUESTION= how did i sleep?
