# %%
#from text2sql.data_utils import data_utils
from text2sql.nlp import Nlp
# Out:
# 2023-06-27 12:11:33.739017: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-27 12:11:33.791300: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-27 12:11:33.792920: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-27 12:11:34.659505: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All model checkpoint layers were used when initializing TFDistilBertForQuestionAnswering.
#
# All the layers of TFDistilBertForQuestionAnswering were initialized from the model checkpoint at distilbert-base-uncased-distilled-squad.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertForQuestionAnswering for predictions without further training.

# %%
#import nltk
#nltk.download('wordnet')
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')

# %%
#from text2sql.data_utils import data_utils
#getSchema=data_utils("data","schema")
#getSchema.get_schema_for_csv("data/oura_sleep.xxx")
nlp = Nlp("data","schema" )

# %%
question = "How  much deep sleep I had last friday?"
distinct = False

# %%
# sql_query = nlp.get_sql_query(df, question, distinct=distinct)
sql_query = nlp.get_sql_query(question)
print("SQL=",sql_query)
print("QUESTION=",question)
# Out:
# {'yesterday': '2023-06-26', 'today': '2023-06-27', 'tomorrow': '2023-06-28', 'last night': '2023-06-26', 'previous night': '2023-06-26', 'this morning': '2023-06-27', 'last week': '2023-06-19 - 2023-06-25', 'previous week': '2023-06-19 - 2023-06-25', 'this week': '2023-06-26 - 2023-07-02', 'next week': '2023-07-03 - 2023-07-09', 'this month': '2023-06-01 - 2023-06-30', 'last month': '2023-05-01 - 2023-05-31', 'previous month': '2023-05-01 - 2023-05-31', 'next month': '2023-07-01 - 2023-07-31', 'next year': '2024-01-01 - 2024-12-31', 'this year': '2023-01-01 - 2023-12-31', 'last year': '2022-01-01 - 2022-12-31', 'previous year': '2022-01-01 - 2022-12-31', 'last weekend': '2023-07-01 - 2023-07-02', 'previous weekend': '2023-07-01 - 2023-07-02', 'this weekend': '2023-07-01 - 2023-07-02', 'next weekend': '2023-07-08 - 2023-07-09', 'first quarter': '2023-01-01 - 2023-03-31', 'second quarter': '2023-04-01 - 2023-06-30', 'third quarter': '2023-07-01 - 2023-09-30', 'fourth quarter': '2023-10-01 - 2023-12-31', 'last monday': '2023-06-26', 'previous monday': '2023-06-26', 'last sunday': '2023-06-25', 'previous sunday': '2023-06-25', 'last saturday': '2023-06-24', 'previous saturday': '2023-06-24', 'last friday': '2023-06-23', 'previous friday': '2023-06-23', 'last thursday': '2023-06-22', 'previous thursday': '2023-06-22', 'last wednesday': '2023-06-21', 'previous wednesday': '2023-06-21', 'last tuesday': '2023-06-20', 'previous tuesday': '2023-06-20'}
# {'name': 'oura_sleep_summary', 'desciption': 'This sleep summary data provides insights into your sleep quality for a specific night. It includes details such as the date of the sleep period, total sleep duration, sleep efficiency percentage, sleep score representing overall sleep quality, and the distribution of different sleep stages (REM, light, and deep sleep). You can use this information to assess how well you slept, the amount of restful sleep obtained, and any potential sleep disturbances. Additionally, metrics like heart rate, restlessness, and temperature deviation offer further context. With these details, you can evaluate your sleep patterns and make adjustments to improve your overall sleep health.', 'keywords': ['Sleep', 'Bedtime', 'Wake-up', 'Duration', 'Deep sleep', 'REM sleep', 'Light sleep', 'Awake time', 'Heart rate', 'Sleep score', 'Efficiency', 'Chapter', 'Temperature', 'Breathing rate', 'Sleep stages', 'Sleep quality', 'Sleep disturbances', 'HRV (Heart rate variability)', 'Sleep schedule'], 'columns': [{'name': 'summary_date', 'keywords': ['date', 'day', 'night', 'sleep date', 'last night', 'latest'], 'type': 'DateTime', 'desciption': 'The date of the sleep period, representing the day before the sleep period ended'}, {'name': 'bedtime_start', 'keywords': ['sleep start time', 'bedtime start', 'start time', 'when I went to bed', 'bedtime'], 'type': 'Timestamp', 'desciption': 'The local time when the sleep period started'}, {'name': 'bedtime_end', 'keywords': ['sleep end time', 'bedtime end', 'end time', 'when I woke up', 'wake-up time'], 'type': 'Timestamp', 'desciption': 'The local time when the sleep period ended'}, {'name': 'duration', 'keywords': ['sleep length', 'total sleep time', 'how long I slept'], 'type': 'Integer', 'desciption': 'The total duration of the sleep period in seconds', 'summable': 'True'}, {'name': 'total', 'keywords': ['total sleep duration', 'overall sleep time', 'total time asleep', 'total sleep'], 'type': 'Integer', 'desciption': 'The total amount of sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'awake', 'keywords': ['awake time', 'time awake', 'time spent awake', 'wakeful period'], 'type': 'Integer', 'desciption': 'The total amount of awake time in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'rem', 'keywords': ['REM sleep', 'rapid eye movement sleep', 'active dreaming phase', 'dreaming'], 'type': 'Integer', 'desciption': 'The total amount of REM sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'light', 'keywords': ['light sleep', 'light restful phase', 'light rest'], 'type': 'Integer', 'desciption': 'The total amount of light sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'deep', 'keywords': ['deep sleep', 'deep restorative phase', 'deep rest'], 'type': 'Integer', 'desciption': 'The total amount of deep sleep in seconds registered during the sleep period', 'summable': 'True'}, {'name': 'hr_lowest', 'keywords': ['lowest heart rate', 'minimum pulse rate', 'lowest heartbeat', 'minimum heart rate'], 'type': 'Integer', 'desciption': 'The lowest heart rate (5-minute sliding average) registered during the sleep period', 'summable': 'True'}, {'name': 'hr_average', 'keywords': ['average heart rate', 'mean pulse rate', 'typical heartbeat', 'mean heart rate'], 'type': 'Integer', 'desciption': 'The average heart rate registered during the sleep period', 'summable': 'True'}, {'name': 'hr_5min', 'keywords': ['heart rate intervals', 'heartbeat readings', 'heartbeats'], 'type': 'String', 'desciption': 'The average heart rate for each beginning 5 minutes of the sleep period'}, {'name': 'efficiency', 'keywords': ['sleep efficiency percentage', 'sleep effectiveness', 'how well I slept'], 'type': 'Integer', 'desciption': 'The sleep efficiency percentage, representing the proportion of time spent asleep', 'summable': 'True'}, {'name': 'onset_latency', 'keywords ...
# QUESTION  How  much deep sleep I had ?
# COLNAME  summary_date
# COLTYPE  DateTime
# COL QUERY which date?
# QA  which date? How  much deep sleep I had ?
# ANSWER  how much deep sleep i had? [SEP]
# ANSWER IDX  5 12
# Answer: how much deep sleep i had?
# Total Score: 0.14675331
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s summary_date how much deep sleep i had?  0.14675331
# COLNAME  bedtime_start
# COLTYPE  Timestamp
# COL QUERY which sleep start time?
# QA  which sleep start time? How  much deep sleep I had ?
# ANSWER  how much deep sleep
# ANSWER IDX  7 10
# Answer: how much deep sleep
# Total Score: 0.14048214
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep']
# filling slots %s %s %s bedtime_start how much deep sleep 0.14048214
# COLNAME  bedtime_end
# COLTYPE  Timestamp
# COL QUERY which sleep end time?
# QA  which sleep end time? How  much deep sleep I had ?
# ANSWER  how much deep sleep i had? [SEP]
# ANSWER IDX  7 14
# Answer: how much deep sleep i had?
# Total Score: 0.14324456
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s bedtime_end how much deep sleep i had?  0.14324456
# COLNAME  duration
# COLTYPE  Integer
# COL QUERY number of sleep length?
# QA  number of sleep length? How  much deep sleep I had ?
# ANSWER  how much deep sleep i had? [SEP]
# ANSWER IDX  7 14
# Answer: how much deep sleep i had?
# Total Score: 0.25127897
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s duration how much deep sleep i had?  0.25127897
# COLNAME  total
# COLTYPE  Integer
# COL QUERY number of total sleep duration?
# QA  number of total sleep duration? How  much deep sleep I had ?
# ANSWER  how much deep sleep i had? [SEP]
# ANSWER IDX  8 15
# Answer: how much deep sleep i had?
# Total Score: 0.3242483
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s total how much deep sleep i had?  0.3242483
# COLNAME  awake
# COLTYPE  Integer
# COL QUERY number of awake time?
# QA  number of awake time? How  much deep sleep I had ?
# ANSWER  how much deep sleep
# ANSWER IDX  7 10
# Answer: how much deep sleep
# Total Score: 0.2547222
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep']
# filling slots %s %s %s awake how much deep sleep 0.2547222
# COLNAME  rem
# COLTYPE  Integer
# COL QUERY number of REM sleep?
# QA  number of REM sleep? How  much deep sleep I had ?
# ANSWER  how much deep sleep i had? [SEP]
# ANSWER IDX  8 15
# Answer: how much deep sleep i had?
# Total Score: 0.30400866
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s rem how much deep sleep i had?  0.30400866
# COLNAME  light
# COLTYPE  Integer
# COL QUERY number of light sleep?
# QA  number of light sleep? How  much deep sleep I had ?
# ANSWER  how much deep sleep i had? [SEP]
# ANSWER IDX  7 14
# Answer: how much deep sleep i had?
# Total Score: 0.28041598
# FIND  ['How', 'much', 'deep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s light how much deep sleep i had?  0.28041598
# COLNAME  deep
# COLTYPE  Integer
# COL QUERY number of deep sleep?
# QA  number of deep sleep? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  7 15
# Answer: how much deep sleep sleep i had?
# Total Score: 0.36255306
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s deep how much deep sleep sleep i had?  0.36255306
# COLNAME  hr_lowest
# COLTYPE  Integer
# COL QUERY number of lowest heart rate?
# QA  number of lowest heart rate? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.27217403
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s hr_lowest how much deep sleep sleep i had?  0.27217403
# COLNAME  hr_average
# COLTYPE  Integer
# COL QUERY number of average heart rate?
# QA  number of average heart rate? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.29558563
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s hr_average how much deep sleep sleep i had?  0.29558563
# COLNAME  hr_5min
# COLTYPE  String
# COL QUERY which heart rate intervals?
# QA  which heart rate intervals? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  7 15
# Answer: how much deep sleep sleep i had?
# Total Score: 0.2478663
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s hr_5min how much deep sleep sleep i had?  0.2478663
# COLNAME  efficiency
# COLTYPE  Integer
# COL QUERY number of sleep efficiency percentage?
# QA  number of sleep efficiency percentage? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.36641675
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s efficiency how much deep sleep sleep i had?  0.36641675
# COLNAME  onset_latency
# COLTYPE  Integer
# COL QUERY number of sleep onset time?
# QA  number of sleep onset time? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.3575196
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s onset_latency how much deep sleep sleep i had?  0.3575196
# COLNAME  midpoint_time
# COLTYPE  Integer
# COL QUERY number of sleep midpoint?
# QA  number of sleep midpoint? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.33465582
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s midpoint_time how much deep sleep sleep i had?  0.33465582
# COLNAME  restless
# COLTYPE  Integer
# COL QUERY number of restlessness percentage?
# QA  number of restlessness percentage? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.323694
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s restless how much deep sleep sleep i had?  0.323694
# COLNAME  temperature_delta
# COLTYPE  Decimal
# COL QUERY number of temperature deviation?
# QA  number of temperature deviation? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  7 15
# Answer: how much deep sleep sleep i had?
# Total Score: 0.2740544
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s temperature_delta how much deep sleep sleep i had?  0.2740544
# COLNAME  breath_average
# COLTYPE  Decimal
# COL QUERY number of average respiratory rate?
# QA  number of average respiratory rate? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.28024524
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s breath_average how much deep sleep sleep i had?  0.28024524
# COLNAME  score
# COLTYPE  Integer
# COL QUERY number of sleep quality score?
# QA  number of sleep quality score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.32544956
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score how much deep sleep sleep i had?  0.32544956
# COLNAME  score_total
# COLTYPE  Integer
# COL QUERY number of sleep duration score?
# QA  number of sleep duration score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.3449453
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_total how much deep sleep sleep i had?  0.3449453
# COLNAME  score_rem
# COLTYPE  Integer
# COL QUERY number of REM sleep score?
# QA  number of REM sleep score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  9 17
# Answer: how much deep sleep sleep i had?
# Total Score: 0.33392143
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_rem how much deep sleep sleep i had?  0.33392143
# COLNAME  score_deep
# COLTYPE  Integer
# COL QUERY number of deep sleep score?
# QA  number of deep sleep score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.34936884
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_deep how much deep sleep sleep i had?  0.34936884
# COLNAME  score_efficiency
# COLTYPE  Integer
# COL QUERY number of sleep efficiency score?
# QA  number of sleep efficiency score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.33926898
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_efficiency how much deep sleep sleep i had?  0.33926898
# COLNAME  score_latency
# COLTYPE  Integer
# COL QUERY number of sleep onset latency score?
# QA  number of sleep onset latency score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  10 18
# Answer: how much deep sleep sleep i had?
# Total Score: 0.36871955
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_latency how much deep sleep sleep i had?  0.36871955
# COLNAME  score_disturbances
# COLTYPE  Integer
# COL QUERY number of sleep disturbances score?
# QA  number of sleep disturbances score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.34899905
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_disturbances how much deep sleep sleep i had?  0.34899905
# COLNAME  score_alignment
# COLTYPE  Integer
# COL QUERY number of sleep schedule alignment score?
# QA  number of sleep schedule alignment score? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  9 17
# Answer: how much deep sleep sleep i had?
# Total Score: 0.31550172
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s score_alignment how much deep sleep sleep i had?  0.31550172
# COLNAME  hypnogram_5min
# COLTYPE  String
# COL QUERY which sleep stage sequence?
# QA  which sleep stage sequence? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  7 15
# Answer: how much deep sleep sleep i had?
# Total Score: 0.11181158
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s hypnogram_5min how much deep sleep sleep i had?  0.11181158
# COLNAME  rmssd
# COLTYPE  Integer
# COL QUERY number of average HRV?
# QA  number of average HRV? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  8 16
# Answer: how much deep sleep sleep i had?
# Total Score: 0.23363315
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s rmssd how much deep sleep sleep i had?  0.23363315
# COLNAME  rmssd_5min
# COLTYPE  String
# COL QUERY which HRV per 5 minutes?
# QA  which HRV per 5 minutes? How  much deep sleep sleep I had ?
# ANSWER  how much deep sleep sleep i had? [SEP]
# ANSWER IDX  9 17
# Answer: how much deep sleep sleep i had?
# Total Score: 0.2153022
# FIND  ['How', 'much', 'deep', 'sleep', 'sleep', 'I', 'had', '?']
# FIND  ['how', 'much', 'deep', 'sleep', 'sleep', 'i', 'had', '?']
# filling slots %s %s %s rmssd_5min how much deep sleep sleep i had?  0.2153022
# SLOTS AFTER SORT  [('score_latency', 'Integer', 'how much deep sleep sleep i had? ', 0.36871955, -1, 6), ('efficiency', 'Integer', 'how much deep sleep sleep i had? ', 0.36641675, -1, 6), ('deep', 'Integer', 'how much deep sleep sleep i had? ', 0.36255306, -1, 6), ('onset_latency', 'Integer', 'how much deep sleep sleep i had? ', 0.3575196, -1, 6), ('score_deep', 'Integer', 'how much deep sleep sleep i had? ', 0.34936884, -1, 6), ('score_disturbances', 'Integer', 'how much deep sleep sleep i had? ', 0.34899905, -1, 6), ('score_total', 'Integer', 'how much deep sleep sleep i had? ', 0.3449453, -1, 6), ('score_efficiency', 'Integer', 'how much deep sleep sleep i had? ', 0.33926898, -1, 6), ('midpoint_time', 'Integer', 'how much deep sleep sleep i had? ', 0.33465582, -1, 6), ('score_rem', 'Integer', 'how much deep sleep sleep i had? ', 0.33392143, -1, 6), ('score', 'Integer', 'how much deep sleep sleep i had? ', 0.32544956, -1, 6), ('total', 'Integer', 'how much deep sleep i had? ', 0.3242483, -1, 5), ('restless', 'Integer', 'how much deep sleep sleep i had? ', 0.323694, -1, 6), ('score_alignment', 'Integer', 'how much deep sleep sleep i had? ', 0.31550172, -1, 6), ('rem', 'Integer', 'how much deep sleep i had? ', 0.30400866, -1, 5), ('hr_average', 'Integer', 'how much deep sleep sleep i had? ', 0.29558563, -1, 6), ('light', 'Integer', 'how much deep sleep i had? ', 0.28041598, -1, 5), ('breath_average', 'Decimal', 'how much deep sleep sleep i had? ', 0.28024524, -1, 6), ('temperature_delta', 'Decimal', 'how much deep sleep sleep i had? ', 0.2740544, -1, 6), ('hr_lowest', 'Integer', 'how much deep sleep sleep i had? ', 0.27217403, -1, 6), ('awake', 'Integer', 'how much deep sleep', 0.2547222, -1, 2), ('duration', 'Integer', 'how much deep sleep i had? ', 0.25127897, -1, 5), ('hr_5min', 'String', 'how much deep sleep sleep i had? ', 0.2478663, -1, 6), ('rmssd', 'Integer', 'how much deep sleep sleep i had? ', 0.23363315, -1, 6), ('rmssd_5min', 'String', 'how much deep sleep sleep i had? ', 0.2153022, -1, 6), ('summary_date', 'DateTime', 'how much deep sleep i had? ', 0.14675331, -1, 5), ('bedtime_end', 'Timestamp', 'how much deep sleep i had? ', 0.14324456, -1, 5), ('bedtime_start', 'Timestamp', 'how much deep sleep', 0.14048214, -1, 2), ('hypnogram_5min', 'String', 'how much deep sleep sleep i had? ', 0.11181158, -1, 6)]
# SLOTS AFTER SORT  0.36871955
# SLOTS  []
# GOT SLOTS  []
# 2023-06-27 12:11:49.704526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype string
# 	 [[{{node inputs}}]]
# 1/1 [==============================] - 0s 111ms/step
# QUESTION  SELECT COUNT({}) FROM {}
# 1/1 [==============================] - 0s 19ms/step
# QUESTION2  SELECT SUM(deep) FROM oura_sleep_summary
# SCHEMA 0  {'name': 'summary_date', 'keywords': ['date', 'day', 'night', 'sleep date', 'last night', 'latest'], 'type': 'DateTime', 'desciption': 'The date of the sleep period, representing the day before the sleep period ended'}
# QUESTION3  SELECT SUM(deep) FROM oura_sleep_summary
# SQL= SELECT SUM(deep) FROM oura_sleep_summary WHERE summary_date = 2023-06-23
# QUESTION= How  much deep sleep I had last friday?

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (4.29.2)
# Requirement already satisfied: numpy>=1.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (1.23.5)
# Requirement already satisfied: filelock in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (3.12.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (2023.5.5)
# Requirement already satisfied: requests in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: packaging>=20.0 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (4.65.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from transformers) (0.15.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages (from requests->transformers) (3.4)

# %%
from transformers import pipeline
model = "tro9999/my_test_big_ner_model"
ner_pipeline = pipeline("ner", model=model)

text = "how did i sleep last night?"
result = ner_pipeline(text)
print(result)
# Out:
# [{'entity': 'B-SCONJ', 'score': 0.5785049, 'index': 1, 'word': 'how', 'start': 0, 'end': 3}, {'entity': 'B-PRON', 'score': 0.99429685, 'index': 3, 'word': 'i', 'start': 8, 'end': 9}, {'entity': 'B-VERB', 'score': 0.9882465, 'index': 4, 'word': 'sleep', 'start': 10, 'end': 15}, {'entity': 'B-TIME', 'score': 0.95321864, 'index': 5, 'word': 'last', 'start': 16, 'end': 20}, {'entity': 'I-TIME', 'score': 0.97035754, 'index': 6, 'word': 'night', 'start': 21, 'end': 26}]

# %%
result
# Out:
# [{'label': 'B-LANGUAGE', 'score': 0.033487215638160706}]
