# %%
#from text2sql.data_utils import data_utils
from text2sql.nlp import Nlp
# Out:
# 2023-06-22 11:18:24.514005: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-22 11:18:24.564786: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-06-22 11:18:24.565793: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-22 11:18:25.770372: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# All model checkpoint layers were used when initializing TFDistilBertForQuestionAnswering.
#
# All the layers of TFDistilBertForQuestionAnswering were initialized from the model checkpoint at distilbert-base-uncased-distilled-squad.
# ...

# %%
#import nltk
#nltk.download('wordnet')
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('averaged_perceptron_tagger')

# %%
#from text2sql.data_utils import data_utils
#getSchema=data_utils("data","schema")
#getSchema.get_schema_for_csv("data/oura_sleep.xxx")
nlp = Nlp("data","schema" )

# %%
question = "how did i sleep 2023-06-22?"
distinct = False

# %%
# sql_query = nlp.get_sql_query(df, question, distinct=distinct)
sql_query = nlp.get_sql_query(question)
print("SQL=",sql_query)
print("QUESTION=",question)
# Out:
# {'name': 'oura_sleep_summary', 'desciption': 'This sleep summary data provides insights into your sleep quality for a specific night. It includes details such as the date of the sleep period, total sleep duration, sleep efficiency percentage, sleep score representing overall sleep quality, and the distribution of different sleep stages (REM, light, and deep sleep). You can use this information to assess how well you slept, the amount of restful sleep obtained, and any potential sleep disturbances. Additionally, metrics like heart rate, restlessness, and temperature deviation offer further context. With these details, you can evaluate your sleep patterns and make adjustments to improve your overall sleep health.', 'keywords': ['Sleep', 'Bedtime', 'Wake-up', 'Duration', 'Deep sleep', 'REM sleep', 'Light sleep', 'Awake time', 'Heart rate', 'Sleep score', 'Efficiency', 'Chapter', 'Temperature', 'Breathing rate', 'Sleep stages', 'Sleep quality', 'Sleep disturbances', 'HRV (Heart rate vari
# ...

# %%
from text2sql.get_time_period_dates import get_time_period_dates
from datetime import date

# %%
current_date = date(2023, 6, 22)  # Replace with your desired current date
result = get_time_period_dates(current_date)
#for term, iso_date in result.items():
#    print(f'{term}: {iso_date}')
#current_date.month
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7469/700295933.py in <cell line: 2>()
#       1 current_date = date(2023, 6, 10)  # Replace with your desired current date
# ----> 2 result = get_time_period_dates(current_date)
#       3 #for term, iso_date in result.items():
#       4 #    print(f'{term}: {iso_date}')
#       5 #current_date.month
#
# ~/sagemaker-studiolab-notebooks/test-transformers/text2sql/get_time_period_dates.py in get_time_period_dates(current_date)
#      62     # Calculate ISO 8601 date for last quarter
#      63     print(current_date)
# ---> 64     current_quarter = (current_date.month - 1) // 3 + 1
#      65     print(current_quarter)
#      66     last_quarter_month = ((current_quarter - 2) * 3) % 12
#
# ValueError: month must be in 1..12
